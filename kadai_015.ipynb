# %%
class Human():
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"Name:{self.name},Age:{self.age}")

# %%
person = Human("侍太郎","42")

# %%
person.printinfo()
# Out:
# Name:侍太郎,Age:42
